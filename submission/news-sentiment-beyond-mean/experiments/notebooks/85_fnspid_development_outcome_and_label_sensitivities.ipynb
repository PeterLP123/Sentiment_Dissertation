# %% [markdown]
# # 85 — FNSPID development outcome and label sensitivities
#
# Post-hoc measurement tests, frozen after the headline next-open hard-share
# result. Three new estimands form one BH family. They do not join the original
# nine-rule comparison or the Notebook 73 ledger. Notebook 75 stays sealed.
#
# 1. Close-to-close SPY-adjusted return with hard negative share.
# 2. Trailing FF3 residual of close-to-close returns with hard negative share.
# 3. Next-open SPY-adjusted return with soft negative mass `mean(p_negative)`.
#
# A surviving sensitivity does not upgrade H1. A failure is a limit on that
# estimand, not permission to retune factors, windows, LSEG or prompts.

# %%
from __future__ import annotations

import json
import sys
from pathlib import Path

import pandas as pd
from IPython.display import Markdown, display

ROOT = Path.cwd().resolve()
if ROOT.name == "experiments":
    ROOT = ROOT.parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from experiments.lib.outcome_label_sensitivities import run  # noqa: E402

NB75 = ROOT / "experiments/notebooks/75_fnspid_evaluation_beyond_mean_replication.ipynb"
assert NB75.exists(), "sealed evaluation notebook must remain in the repository"
print(f"repo: {ROOT}")
print(f"sealed notebook 75 present: {NB75.exists()}")

# %%
written = run()
table = pd.read_csv(written["coefficients"])
coverage = pd.read_csv(written["coverage"])
display(Markdown("## Coverage"))
display(coverage)
display(Markdown("## Coefficients"))
display(table)
print(json.dumps({k: str(v) for k, v in written.items()}, indent=2))
